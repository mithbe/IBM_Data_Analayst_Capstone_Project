# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45** minutes

# %% [markdown]
# In this lab, you will perform data wrangling tasks to prepare raw data for analysis. Data wrangling involves cleaning, transforming, and organizing data into a structured format suitable for analysis. This lab focuses on tasks like identifying inconsistencies, encoding categorical variables, and feature transformation.

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab, you will be able to:

# %% [markdown]
# - Identify and remove inconsistent data entries.
#
# - Encode categorical variables for analysis.
#
# - Handle missing values using multiple imputation strategies.
#
# - Apply feature scaling and transformation techniques.

# %% [markdown]
# #### Intsall the required libraries

# %%
# !pip install pandas
# !pip install matplotlib
# Out:
# Collecting pandas
#   Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.2-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 109.7 MB/s eta 0:00:00
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 150.7 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.4 pandas-3.0.2
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.4.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (24.2)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.12/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 128.4 MB/s eta 0:00:00
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 114.0 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 51.8 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 106.8 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.2.0 pyparsing-3.3.2

# %% [markdown]
# ## Tasks

# %% [markdown]
# #### Step 1: Import the necessary module.

# %% [markdown]
# ### 1. Load the Dataset

# %% [markdown]
# <h5>1.1 Import necessary libraries and load the dataset.</h5>

# %% [markdown]
# Ensure the dataset is loaded correctly by displaying the first few rows.

# %%
# Import necessary libraries
import pandas as pd

# Load the Stack Overflow survey data
dataset_url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/n01PQ9pSmiRX6520flujwQ/survey-data.csv"
df = pd.read_csv(dataset_url)

# Display the first few rows
print(df.head())
# Out:
#    ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
# 2           3  I am a developer by profession     45-54 years old
# 3           4           I am learning to code     18-24 years old
# 4           5  I am a developer by profession     18-24 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# 1  Employed, full-time     Remote  Apples
# 2  Employed, full-time     Remote  Apples
# 3   Student, full-time        NaN  Apples
# 4   Student, full-time        NaN  Apples
#
#                                     CodingActivities  \
# 0                                              Hobby
# 1  Hobby;Contribute to open-source projects;Other...
# 2  Hobby;Contribute to open-source projects;Other...
# 3                                                NaN
# 4                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  \
# 0                             Books / Physical media
# 1  Books / Physical media;Colleague;On the job tr...
# 2  Books / Physical media;Colleague;On the job tr...
# 3  Other online resources (e.g., videos, blogs, f...
# 4  Other online resources (e.g., videos, blogs, f...
#
#                                      LearnCodeOnline  ... JobSatPoints_6  \
# 0                                                NaN  ...            NaN
# 1  Technical documentation;Blogs;Books;Written Tu...  ...            0.0
# 2  Technical documentation;Blogs;Books;Written Tu...  ...            NaN
# 3  Stack Overflow;How-to videos;Interactive tutorial  ...            NaN
# 4  Technical documentation;Blogs;Written Tutorial...  ...            NaN
#
#   JobSatPoints_7 JobSatPoints_8 JobSatPoints_9 JobSatPoints_10  \
# 0            NaN            NaN            NaN             NaN
# 1            0.0            0.0            0.0             0.0
# 2            NaN            NaN            NaN             NaN
# 3            NaN            NaN            NaN             NaN
# 4            NaN            NaN            NaN             NaN
#
#   JobSatPoints_11           SurveyLength SurveyEase ConvertedCompYearly JobSat
# 0             NaN                    NaN        NaN                 NaN    NaN
# 1             0.0                    NaN        NaN                 NaN    NaN
# 2             NaN  Appropriate in length       Easy                 NaN    NaN
# 3             NaN               Too long       Easy                 NaN    NaN
# 4             NaN              Too short       Easy                 NaN    NaN
#
# [5 rows x 114 columns]

# %% [markdown]
# #### 2. Explore the Dataset

# %% [markdown]
# <h5>2.1 Summarize the dataset by displaying the column data types, counts, and missing values.</h5>

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), str(100)
# memory usage: 56.9 MB

# %%
# Write your code here
print(df.dtypes)
print(df.count())
print(df.isnull().sum())
# Out:
# ResponseId               int64
# MainBranch                 str
# Age                        str
# Employment                 str
# RemoteWork                 str
#                         ...
# JobSatPoints_11        float64
# SurveyLength               str
# SurveyEase                 str
# ConvertedCompYearly    float64
# JobSat                 float64
# Length: 114, dtype: object
# ResponseId             65437
# MainBranch             65437
# Age                    65437
# Employment             65437
# RemoteWork             54806
#                        ...
# JobSatPoints_11        29445
# SurveyLength           56182
# SurveyEase             56238
# ConvertedCompYearly    23435
# JobSat                 29126
# Length: 114, dtype: int64
# ResponseId                 0
# MainBranch                 0
# Age                        0
# Employment                 0
# RemoteWork             10631
#                        ...
# JobSatPoints_11        35992
# SurveyLength            9255
# SurveyEase              9199
# ConvertedCompYearly    42002
# JobSat                 36311
# Length: 114, dtype: int64

# %% [markdown]
# <h5>2.2 Generate basic statistics for numerical columns.</h5>

# %%
# Write your code here
df.describe()
# Out:
#          ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# 25%          0.000000        0.000000        0.000000         0.00000
# 50%          0.000000        0.000000       20.000000        15.00000
# 75%          5.000000       10.000000       30.000000        30.00000
# max        100.000000      100.000000      100.000000       100.00000
#
#        JobSatPoints_8  JobSatPoints_9  JobSatPoints_10  JobSatPoints_11  \
# count    29456.000000    29456.000000     29450.000000     29445.000000
# mean        20.278165       16.169432        10.955713         9.953948
# std         26.108110       24.845032        22.906263        21.775652
# min          0.000000        0.000000         0.000000         0.000000
# 25%          0.000000        0.000000         0.000000         0.000000
# 50%         10.000000        5.000000         0.000000         0.000000
# 75%         25.000000       20.000000        10.000000        10.000000
# max        100.000000      100.000000       100.000000       100.000000
#
#        ConvertedCompYearly        JobSat
# count         2.343500e+04  29126.000000
# mean          8.615529e+04      6.935041
# std           1.867570e+05      2.088259
# min           1.000000e+00      0.000000
# 25%           3.271200e+04      6.000000
# 50%           6.500000e+04      7.000000
# 75%           1.079715e+05      8.000000
# max           1.625660e+07     10.000000

# %% [markdown]
# ### 3. Identifying and Removing Inconsistencies

# %% [markdown]
# <h5>3.1 Identify inconsistent or irrelevant entries in specific columns (e.g., Country).</h5>

# %%
# Write your code here
cat_cols = df.select_dtypes(include=['object', 'category']).columns
print(cat_cols)
# Out:
# Index(['MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        'TechDoc', 'YearsCode', 'YearsCodePro', 'DevType', 'OrgSize',
#        'PurchaseInfluence', 'BuyNewTool', 'BuildvsBuy', 'TechEndorse',
#        'Country', 'Currency', 'LanguageHaveWorkedWith',
#        'LanguageWantToWorkWith', 'LanguageAdmired', 'DatabaseHaveWorkedWith',
#        'DatabaseWantToWorkWith', 'DatabaseAdmired', 'PlatformHaveWorkedWith',
#        'PlatformWantToWorkWith', 'PlatformAdmired', 'WebframeHaveWorkedWith',
#        'WebframeWantToWorkWith', 'WebframeAdmired', 'EmbeddedHaveWorkedWith',
#        'EmbeddedWantToWorkWith', 'EmbeddedAdmired', 'MiscTechHaveWorkedWith',
#        'MiscTechWantToWorkWith', 'MiscTechAdmired', 'ToolsTechHaveWorkedWith',
#        'ToolsTechWantToWorkWith', 'ToolsTechAdmired',
#        'NEWCollabToolsHaveWorkedWith', 'NEWCollabToolsWantToWorkWith',
#        'NEWCollabToolsAdmired', 'OpSysPersonal use', 'OpSysProfessional use',
#        'OfficeStackAsyncHaveWorkedWith', 'OfficeStackAsyncWantToWorkWith',
#        'OfficeStackAsyncAdmired', 'OfficeStackSyncHaveWorkedWith',
#        'OfficeStackSyncWantToWorkWith', 'OfficeStackSyncAdmired',
#        'AISearchDevHaveWorkedWith', 'AISearchDevWantToWorkWith',
#        'AISearchDevAdmired', 'NEWSOSites', 'SOVisitFreq', 'SOAccount',
#        'SOPartFreq', 'SOHow', 'SOComm', 'AISelect', 'AISent', 'AIBen', 'AIAcc',
#        'AIComplex', 'AIToolCurrently Using', 'AIToolInterested in Using',
#        'AIToolNot interested in Using', 'AINextMuch more integrated',
#        'AINextNo change', 'AINextMore integrated', 'AINextLess integrated',
#        'AINextMuch less integrated', 'AIThreat', 'AIEthics', 'AIChallenges',
#        'TBranch', 'ICorPM', 'Knowledge_1', 'Knowledge_2', 'Knowledge_3',
#        'Knowledge_4', 'Knowledge_5', 'Knowledge_6', 'Knowledge_7',
#        'Knowledge_8', 'Knowledge_9', 'Frequency_1', 'Frequency_2',
#        'Frequency_3', 'TimeSearching', 'TimeAnswering', 'Frustration',
#        'ProfessionalTech', 'ProfessionalCloud', 'ProfessionalQuestion',
#        'Industry', 'SurveyLength', 'SurveyEase'],
#       dtype='str')
# /tmp/ipykernel_301/2268126806.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   cat_cols = df.select_dtypes(include=['object', 'category']).columns

# %%
for col in cat_cols:
    print(f"\nColumn: {col}")
    print(df[col].unique())
# Out:
# Column: MainBranch
# <StringArray>
# [                                                       'I am a developer by profession',
#                                                                  'I am learning to code',
#                                                            'I code primarily as a hobby',
#  'I am not primarily a developer, but I write code sometimes as part of my work/studies',
#                               'I used to be a developer by profession, but no longer am']
# Length: 5, dtype: str
#
# Column: Age
# <StringArray>
# ['Under 18 years old',    '35-44 years old',    '45-54 years old',
#     '18-24 years old',    '25-34 years old',    '55-64 years old',
#   'Prefer not to say',  '65 years or older']
# Length: 8, dtype: str
#
# Column: Employment
# <StringArray>
# [                                                                                                                                                          'Employed, full-time',
#                                                                                                                                                             'Student, full-time',
#                                                                                                                          'Student, full-time;Not employed, but looking for work',
#                                                                                                                           'Independent contractor, freelancer, or self-employed',
#                                                                                                                                         'Not employed, and not looking for work',
#                                                                                                                                         'Employed, full-time;Student, part-time',
#                                                                                                       'Employed, full-time;Independent contractor, freelancer, or self-employed',
#                                                                                                                                         'Employed, full-time;Student, full-time',
#                                                                                                                                                            'Employed, part-time',
#                                                                                                                                         'Student, full-time;Employed, part-time',
#  ...
#                                                                                   'Not employed, but looking for work;Not employed, and not looking for work;Student, part-time',
#                                                         'Employed, full-time;Student, full-time;Independent contractor, freelancer, or self-employed;Student, part-time;Retired',
#                                                               'Employed, full-time;Student, full-time;Not employed, but looking for work;Student, part-time;Employed, part-time',
#           'Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Student, part-time',
#  'Employed, full-time;Student, full-time;Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Employed, part-time;Retired',
#                             'Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time',
#                                                                                                                                                     'Student, full-time;Retired',
#                                                                                                      'Employed, full-time;Not employed, but looking for work;Student, part-time',
#                                                                                                  'Not employed, and not looking for work;Student, part-time;Employed, part-time',
#                                                             'Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Retired']
# Length: 110, dtype: str
#
# Column: RemoteWork
# <StringArray>
# ['Remote', nan, 'In-person', 'Hybrid (some remote, some in-person)']
# Length: 4, dtype: str
#
# Column: Check
# <StringArray>
# ['Apples']
# Length: 1, dtype: str
#
# Column: CodingActivities
# <StringArray>
# [                                                                                                                                                                          'Hobby',
#                                                                                                                 'Hobby;Contribute to open-source projects;Other (please specify):',
#                                                                                                                                                                                nan,
#                                                                                                                                                     'I don’t code outside of work',
#                                                                                                                                                         'Bootstrapping a business',
#                                                                                                                                         'Hobby;Contribute to open-source projects',
#                                                                                                                                                    'Hobby;School or academic work',
#                                                                     'Hobby;Contribute to open-source projects;Professional development or self-paced learning from online courses',
#                                                                                                        'Hobby;Professional development or self-paced learning from online courses',
#                                                                                                                       'Contribute to open-source projects;Other (please specify):',
#  ...
#                                      'Other (please specify):;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work',
#                                        'Hobby;Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work;Freelance/contract work',
#                                                                                               'Contribute to open-source projects;Other (please specify):;Freelance/contract work',
#                                'Hobby;Other (please specify):;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work',
#                                                                           'Hobby;Other (please specify):;Bootstrapping a business;School or academic work;Freelance/contract work',
#                                                                                                         'Other (please specify):;Bootstrapping a business;School or academic work',
#  'Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work;Professional development or self-paced learning from online courses',
#                                                                'Hobby;Contribute to open-source projects;Other (please specify):;Bootstrapping a business;Freelance/contract work',
#                                                                'Hobby;Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work',
#       'Hobby;Other (please specify):;Bootstrapping a business;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work']
# Length: 119, dtype: str
#
# Column: EdLevel
# <StringArray>
# [                                                         'Primary/elementary school',
#                                        'Bachelor’s degree (B.A., B.S., B.Eng., etc.)',
#                                     'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)',
#                              'Some college/university study without earning a degree',
#  'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)',
#                                      'Professional degree (JD, MD, Ph.D, Ed.D, etc.)',
#                                                 'Associate degree (A.A., A.S., etc.)',
#                                                                      'Something else',
#                                                                                   nan]
# Length: 9, dtype: str
#
# Column: LearnCode
# <StringArray>
# [                                                                                                                                                                                                                     'Books / Physical media',
#                                                                                                                   'Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community)',
#                                                                           'Books / Physical media;Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)',
#                                                                                                'Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification',
#                                                                                                                                                                        'Other online resources (e.g., videos, blogs, forum, online community)',
#                                                                                                                                                                      'School (i.e., University, College, etc);Online Courses or Certification',
#                                                                                                                        'Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification;Coding Bootcamp',
#                                                                                                                 'Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification',
#                                                                                                            'On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)',
#                                                                                                         'Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)',
#  ...
#                                                                                                                                         'Books / Physical media;Colleague;On the job training;Friend or family member;Other (please specify):',
#                                                                                                           'Books / Physical media;On the job training;School (i.e., University, College, etc);Friend or family member;Other (please specify):',
#  'Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification;Coding Bootcamp;Friend or family member;Other (please specify):',
#                                                                                                                                                 'Books / Physical media;Colleague;On the job training;Coding Bootcamp;Friend or family member',
#                                                                                                 'Books / Physical media;Colleague;On the job training;School (i.e., University, College, etc);Friend or family member;Other (please specify):',
#                                      'Colleague;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification;Friend or family member;Other (please specify):',
#                                                                                                  'Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);Coding Bootcamp;Other (please specify):',
#                                                                                                                                                          'On the job training;Coding Bootcamp;Friend or family member;Other (please specify):',
#                                                                                                                                'Colleague;On the job training;School (i.e., University, College, etc);Coding Bootcamp;Friend or family member',
#                                                                                                                                                              'School (i.e., University, College, etc);Coding Bootcamp;Friend or family member']
# Length: 419, dtype: str
#
# Column: LearnCodeOnline
# <StringArray>
# [                                                                                                                                                                                                                                                                   nan,
#                                                                                                                                                                                                  'Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow',
#                                                                                                                                                  'Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow;Coding sessions (live or recorded);Social Media',
#                                                                                                                                                                                                                     'Stack Overflow;How-to videos;Interactive tutorial',
#                                                                                                                                                                'Technical documentation;Blogs;Written Tutorials;Stack Overflow;Social Media;Video-based Online Courses',
#                                                                                                                                                                                                   'Technical documentation;Stack Overflow;Written-based Online Courses',
#                                                                                                                                                                                                                    'Technical documentation;Video-based Online Courses',
#                                                                                                                                                                                                                           'Stack Overflow;Written-based Online Courses',
#                                                                                                                                                                                          'Technical documentation;Blogs;Written Tutorials;Stack Overflow;How-to videos',
#                                                                                                                                                                'Technical documentation;Books;Written Tutorials;Stack Overflow;Social Media;Video-based Online Courses',
#  ...
#  'Technical documentation;Blogs;Books;Written Tutorials;How-to videos;Interactive tutorial;Video-based Online Courses;Written-based Online Courses;Certification videos;Online challenges (e.g., daily or weekly coding challenges);Auditory material (e.g., podcasts)',
#                                                                                                                                                                           'Written Tutorials;Stack Overflow;How-to videos;Video-based Online Courses;Programming Games',
#                 'Technical documentation;Books;Written Tutorials;Coding sessions (live or recorded);Social Media;How-to videos;Interactive tutorial;Video-based Online Courses;Written-based Online Courses;AI;Certification videos;Auditory material (e.g., podcasts)',
#                                                                                                               'Coding sessions (live or recorded);Social Media;How-to videos;Video-based Online Courses;AI;Online challenges (e.g., daily or weekly coding challenges)',
#                                                       'Technical documentation;Blogs;Books;Written Tutorials;Coding sessions (live or recorded);How-to videos;Video-based Online Courses;Online challenges (e.g., daily or weekly coding challenges);Programming Games',
#                                                                                              'Technical documentation;Blogs;Books;Written Tutorials;Interactive tutorial;Video-based Online Courses;Written-based Online Courses;AI;Auditory material (e.g., podcasts)',
#                                                                                                                                                                                                            'Coding sessions (live or recorded);AI;Certification videos',
#                                                                             'Technical documentation;Blogs;Written Tutorials;Stack Overflow;Coding sessions (live or recorded);How-to videos;Video-based Online Courses;Written-based Online Courses;Programming Games',
#                                                                       'Technical documentation;Blogs;Books;Written Tutorials;Coding sessions (live or recorded);How-to videos;Written-based Online Courses;Online challenges (e.g., daily or weekly coding challenges)',
#                                                                                                                                                                          'Blogs;Stack Overflow;Social Media;Video-based Online Courses;Written-based Online Courses;AI']
# Length: 10854, dtype: str
#
# Column: TechDoc
# <StringArray>
# [                                                                                                                                                                                                                       nan,
#                                                             'API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine',
#                                                                                        'API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine',
#                                                                                                                                                                                                'First-party knowledge base',
#                                                                                                                                                        'Traditional public search engine;AI-powered search/dev tool (free)',
#                                                      'API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine;AI-powered search/dev tool (free)',
#                                                                                                                                                                                    'API document(s) and/or SDK document(s)',
#                                                                                                                                                   'API document(s) and/or SDK document(s);Traditional public search engine',
#                                                                               'API document(s) and/or SDK document(s);Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid)',
#                                                                                              'API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base',
#  ...
#                                                       'API document(s) and/or SDK document(s);Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):',
#                                                                                                     'First-party knowledge base;Traditional public search engine;AI-powered search/dev tool (free);Other (please specify):',
#                                                                                                                                'Traditional public search engine;AI-powered search/dev tool (free);Other (please specify):',
#                                                                                              'Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):',
#                                                                     'User guides or README files found in the source repository;Traditional public search engine;AI-powered search/dev tool (paid);Other (please specify):',
#                                                                                                                                                                        'First-party knowledge base;Other (please specify):',
#                                                                                                                                'Traditional public search engine;AI-powered search/dev tool (paid);Other (please specify):',
#                                                                                                                               'AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):',
#  'API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):',
#                            'API document(s) and/or SDK document(s);First-party knowledge base;Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):']
# Length: 114, dtype: str
#
# Column: YearsCode
# <StringArray>
# [                 nan,                 '20',                 '37',
#                   '4',                  '9',                 '10',
#                   '7',                  '1',                 '15',
#                  '30',                 '31',                  '6',
#                  '12',                 '22',                  '5',
#                  '36',                 '25',                 '44',
#                  '24',                 '18',                  '3',
#                   '8', 'More than 50 years',                 '11',
#                  '29',                 '40',                 '39',
#                   '2',                 '42',                 '34',
#                  '19',                 '35',                 '16',
#                  '33',                 '13',                 '23',
#                  '14',                 '28',                 '17',
#                  '21',                 '43',                 '46',
#                  '26',                 '32',                 '41',
#                  '45',                 '27',                 '38',
#                  '50',                 '48',                 '47',
#    'Less than 1 year',                 '49']
# Length: 53, dtype: str
#
# Column: YearsCodePro
# <StringArray>
# [                 nan,                 '17',                 '27',
#                   '7',                 '11',                 '25',
#                  '12',                 '10',                  '3',
#    'Less than 1 year',                 '18',                 '37',
#                  '15',                 '20',                  '6',
#                   '2',                 '16',                  '8',
#                  '14',                  '4',                 '45',
#                   '1',                 '24',                 '29',
#                   '5',                 '30',                 '26',
#                   '9',                 '33',                 '13',
#                  '35',                 '23',                 '22',
#                  '31',                 '19',                 '21',
#                  '28',                 '34',                 '32',
#                  '40',                 '50',                 '39',
#                  '44',                 '42',                 '41',
#                  '36',                 '38', 'More than 50 years',
#                  '43',                 '47',                 '48',
#                  '46',                 '49']
# Length: 53, dtype: str
#
# Column: DevType
# <StringArray>
# [                                            nan,
#                          'Developer, full-stack',
#                           'Developer Experience',
#                                        'Student',
#                            'Academic researcher',
#                                'Project manager',
#                             'Developer Advocate',
#                            'Developer, back-end',
#                        'Other (please specify):',
#                           'Developer, front-end',
#                         'Database administrator',
#  'Developer, desktop or enterprise applications',
#                  'Cloud infrastructure engineer',
#  'Data scientist or machine learning specialist',
#                    'Research & Development role',
#    'Developer, embedded applications or devices',
#                           'System administrator',
#                              'DevOps specialist',
#                            'Engineering manager',
#                                       'Designer',
#                          'Security professional',
#           'Senior Executive (C-Suite, VP, etc.)',
#                              'Developer, mobile',
#                    'Developer, game or graphics',
#                       'Data or business analyst',
#                                       'Educator',
#                          'Developer, QA or test',
#                                'Product manager',
#                                  'Developer, AI',
#                                      'Scientist',
#                     'Engineer, site reliability',
#                                     'Blockchain',
#                'Marketing or sales professional',
#                              'Hardware Engineer',
#                                  'Data engineer']
# Length: 35, dtype: str
#
# Column: OrgSize
# <StringArray>
# [                                                 nan,
#                                '100 to 499 employees',
#                                    '2 to 9 employees',
#  'Just me - I am a freelancer, sole proprietor, etc.',
#                                  '10 to 19 employees',
#                                  '20 to 99 employees',
#                            '5,000 to 9,999 employees',
#                            '1,000 to 4,999 employees',
#                                        'I don’t know',
#                            '10,000 or more employees',
#                                '500 to 999 employees']
# Length: 11, dtype: str
#
# Column: PurchaseInfluence
# <StringArray>
# [                               nan,            'I have some influence',
#     'I have little or no influence', 'I have a great deal of influence']
# Length: 4, dtype: str
#
# Column: BuyNewTool
# <StringArray>
# [                                                                                                                                                                                                                                                             nan,
#                                                                          'Start a free trial;Ask developers I know/work with;Ask a generative AI tool;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd',
#                                                                                                                                                                                                                                              'Start a free trial',
#                                                                                                                                                              'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow',
#  'Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#                                                                                                                                                                                         'Ask developers I know/work with;Research companies that have emailed me',
#                                                                                                                                                                      'Ask developers I know/work with;Read ratings or reviews on third party sites like G2 Crowd',
#                                                                                                                                                                                                                                 'Ask developers I know/work with',
#                                                                                                                                             'Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#                                                                                                                            'Start a free trial;Ask developers I know/work with;Ask a generative AI tool;Research companies that have advertised on sites I visit',
#  ...
#                                                                                     'Ask developers I know/work with;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have advertised on sites I visit;Other (please specify):',
#                                                          'Start a free trial;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me;Other (please specify):',
#                                                                                                                                                 'Visit developer communities like Stack Overflow;Research companies that have emailed me;Other (please specify):',
#          'Start a free trial;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me;Other (please specify):',
#                                                                                                                                                              'Read ratings or reviews on third party sites like G2 Crowd;Research companies that have emailed me',
#                                                                                      'Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have emailed me;Other (please specify):',
#                                                                                       'Ask a generative AI tool;Visit developer communities like Stack Overflow;Research companies that have advertised on sites I visit;Research companies that have emailed me',
#                                                                                                        'Ask developers I know/work with;Research companies that have advertised on sites I visit;Research companies that have emailed me;Other (please specify):',
#                                                                                                                                        'Ask developers I know/work with;Ask a generative AI tool;Research companies that have emailed me;Other (please specify):',
#                                                                                                                     'Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me;Other (please specify):']
# Length: 216, dtype: str
#
# Column: BuildvsBuy
# <StringArray>
# [                                                                          nan,
#       'Is ready-to-go but also customizable for growth and targeted use cases',
#  'Is set up to be customized and needs to be engineered into a usable product',
#             'Out-of-the-box is ready to go with little need for customization']
# Length: 4, dtype: str
#
# Column: TechEndorse
# <StringArray>
# [                                                                                                                                                                   nan,
#       'APIs;Customization;Integrated developer community;Quality support system;AI tool integration;Reputation for quality and excellence;Frequent updates to features',
#                                                         'APIs;Integrated developer community;Reputation for quality and excellence;Connected to an open source project',
#                    'APIs;Customization;Integrated developer community;Quality support system;Reputation for quality and excellence;Connected to an open source project',
#                                                                                               'APIs;Reputation for quality and excellence;Frequent updates to features',
#                                                                                                                              'APIs;Connected to an open source project',
#                                                                                        'APIs;Reputation for quality and excellence;Connected to an open source project',
#                                                                     'Integrated developer community;Reputation for quality and excellence;Frequent updates to features',
#                                                                                                                                                         'Customization',
#                                                                                 'APIs;Customization;Reputation for quality and excellence;Frequent updates to features',
#  ...
#                                                                                            'Customization;Integrated developer community;Quality support system;Other:',
#                   'Integrated developer community;Quality support system;AI tool integration;Reputation for quality and excellence;Connected to an open source project',
#                                                                                                    'Integrated developer community;Frequent updates to features;Other:',
#                                                                   'APIs;Quality support system;Frequent updates to features;Connected to an open source project;Other:',
#                                                                                 'Customization;Frequent updates to features;Connected to an open source project;Other:',
#                                                                    'APIs;Integrated developer community;AI tool integration;Connected to an open source project;Other:',
#                                      'APIs;Customization;Integrated developer community;Quality support system;AI tool integration;Frequent updates to features;Other:',
#                                                                                'Integrated developer community;AI tool integration;Frequent updates to features;Other:',
#                                                      'Customization;Integrated developer community;Quality support system;Reputation for quality and excellence;Other:',
#  'APIs;Customization;Integrated developer community;Quality support system;AI tool integration;Frequent updates to features;Connected to an open source project;Other:']
# Length: 387, dtype: str
#
# Column: Country
# <StringArray>
# [                            'United States of America',
#  'United Kingdom of Great Britain and Northern Ireland',
#                                                'Canada',
#                                                'Norway',
#                                            'Uzbekistan',
#                                                'Serbia',
#                                                'Poland',
#                                           'Philippines',
#                                              'Bulgaria',
#                                           'Switzerland',
#  ...
#                                 'Saint Kitts and Nevis',
#                                                'Monaco',
#                    'Micronesia, Federated States of...',
#                                                 'Haiti',
#                                                     nan,
#                                                 'Nauru',
#                                               'Liberia',
#                                                  'Chad',
#                                              'Djibouti',
#                                       'Solomon Islands']
# Length: 186, dtype: str
#
# Column: Currency
# <StringArray>
# [                          nan,        'PKR\tPakistani rupee',
#            'EUR European Euro',   'USD\tUnited States dollar',
#          'BRL\tBrazilian real',         'GBP\tPound sterling',
#            'RON\tRomanian leu',           'INR\tIndian rupee',
#             'CHF\tSwiss franc',           'TRY\tTurkish lira',
#  ...
#  'FKP\tFalkland Islands pound',          'BWP\tBotswana pula',
#          'GGP\tGuernsey Pound',    'CVE\tCape Verdean escudo',
#         'GIP\tGibraltar pound',        'SZL\tSwazi lilangeni',
#    'none\tCook Islands dollar',          'AWG\tAruban florin',
#        'BBD\tBarbadian dollar',       'BMD\tBermudian dollar']
# Length: 143, dtype: str
#
# Column: LanguageHaveWorkedWith
# <StringArray>
# [                                                                                                                                   nan,
#                                                                 'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript',
#                                                                                                                                    'C#',
#                                                                   'C;C++;HTML/CSS;Java;JavaScript;PHP;PowerShell;Python;SQL;TypeScript',
#                                                                                               'C++;HTML/CSS;JavaScript;Lua;Python;Rust',
#                                                         'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Python;Rust;Swift;TypeScript',
#                                                                                                                                     'R',
#                                                                                                        'HTML/CSS;JavaScript;TypeScript',
#                                                                                                                                   'Lua',
#                                                                                                                'JavaScript;Python;Ruby',
#  ...
#                                                                                       'C#;GDScript;HTML/CSS;JavaScript;Python;Ruby;SQL',
#                                                               'Bash/Shell (all shells);C;C#;C++;Go;HTML/CSS;Java;JavaScript;Lua;Python',
#                                                                   'C;C#;C++;Go;HTML/CSS;JavaScript;Objective-C;Python;Swift;TypeScript',
#                                                         'Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript;VBA',
#                                                                                                               'C++;Go;Java;Python;Rust',
#                                                                             'Elixir;HTML/CSS;JavaScript;Lua;PowerShell;Python;Ruby;SQL',
#  'Assembly;Bash/Shell (all shells);C;C++;Dart;HTML/CSS;Java;JavaScript;PowerShell;Rust;Solidity;SQL;TypeScript;VBA;Visual Basic (.Net)',
#            'Bash/Shell (all shells);C;C#;C++;Delphi;Groovy;HTML/CSS;Java;JavaScript;Objective-C;PowerShell;Python;SQL;Swift;TypeScript',
#                                                                                              'C;C++;Go;Lua;Objective-C;Python;Rust;SQL',
#                                                                                      'C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript']
# Length: 23865, dtype: str
#
# Column: LanguageWantToWorkWith
# <StringArray>
# [                                                                                                                                                            nan,
#                                                                                   'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Kotlin;Python;TypeScript',
#                                                                                                                                                             'C#',
#                                                                                                      'HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript',
#                                                                                                                             'C++;HTML/CSS;JavaScript;Lua;Python',
#                                                                                       'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Python;Swift;TypeScript',
#                                                                                                                                                              'R',
#                                                                                                                                 'HTML/CSS;JavaScript;TypeScript',
#                                                                                                                                                            'Lua',
#                                                                                                                         'C#;Crystal;Java;JavaScript;Python;Ruby',
#  ...
#                                                                                                'C#;Elixir;GDScript;HTML/CSS;JavaScript;Ruby;Rust;SQL;TypeScript',
#                                                                            'Bash/Shell (all shells);C;C#;C++;Go;Haskell;HTML/CSS;Java;JavaScript;Lua;Python;Zig',
#                                                                                                                                           'HTML/CSS;Java;MATLAB',
#                                                                               'Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PHP;Python;SQL;TypeScript',
#                                                                                                                               'Clojure;Elixir;Kotlin;Python;SQL',
#                                                                                                                         'Dart;Elixir;Go;Lua;Python;Ruby;SQL;Zig',
#                                                                                                                                              'Elixir;Rust;Swift',
#  'Bash/Shell (all shells);C;C++;Elixir;Erlang;Go;HTML/CSS;Java;JavaScript;Kotlin;Lua;PowerShell;Python;Rust;Solidity;SQL;TypeScript;VBA;Visual Basic (.Net);Zig',
#                                                                                                                  'Bash/Shell (all shells);C;C++;Python;Ruby;SQL',
#                                                     'Bash/Shell (all shells);C#;Go;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;Python;Rust;SQL;Swift;TypeScript']
# Length: 22770, dtype: str
#
# Column: LanguageAdmired
# <StringArray>
# [                                                                                                                     nan,
#                                                   'Bash/Shell (all shells);Go;HTML/CSS;Java;JavaScript;Python;TypeScript',
#                                                                                                                      'C#',
#                                                               'HTML/CSS;Java;JavaScript;PowerShell;Python;SQL;TypeScript',
#                                                                                      'C++;HTML/CSS;JavaScript;Lua;Python',
#                                                'Bash/Shell (all shells);HTML/CSS;Java;JavaScript;Python;Swift;TypeScript',
#                                                                                                                       'R',
#                                                                                          'HTML/CSS;JavaScript;TypeScript',
#                                                                                                                     'Lua',
#                                                                                                  'JavaScript;Python;Ruby',
#  ...
#                                                                                      'C;GDScript;Kotlin;Swift;TypeScript',
#                                                                    'Ada;C++;HTML/CSS;Java;TypeScript;Visual Basic (.Net)',
#                                                                     'Bash/Shell (all shells);Julia;Kotlin;SQL;TypeScript',
#                                                             'C#;HTML/CSS;Java;JavaScript;PHP;SQL;VBA;Visual Basic (.Net)',
#                                                                                'C#;GDScript;HTML/CSS;JavaScript;Ruby;SQL',
# ...
# Length: 6, dtype: str
#
# Column: Knowledge_2
# <StringArray>
# [                         nan,                   'Disagree',
#                       'Agree', 'Neither agree nor disagree',
#              'Strongly agree',          'Strongly disagree']
# Length: 6, dtype: str
#
# Column: Knowledge_3
# <StringArray>
# [                         nan,                      'Agree',
#              'Strongly agree', 'Neither agree nor disagree',
#                    'Disagree',          'Strongly disagree']
# Length: 6, dtype: str
#
# Column: Knowledge_4
# <StringArray>
# [                         nan,                      'Agree',
#                    'Disagree',             'Strongly agree',
#  'Neither agree nor disagree',          'Strongly disagree']
# Length: 6, dtype: str
#
# Column: Knowledge_5
# <StringArray>
# [                         nan,                      'Agree',
#  'Neither agree nor disagree',             'Strongly agree',
#                    'Disagree',          'Strongly disagree']
# Length: 6, dtype: str
#
# Column: Knowledge_6
# <StringArray>
# [                         nan, 'Neither agree nor disagree',
#              'Strongly agree',          'Strongly disagree',
#                       'Agree',                   'Disagree']
# Length: 6, dtype: str
#
# Column: Knowledge_7
# <StringArray>
# [                         nan,                   'Disagree',
#                       'Agree',             'Strongly agree',
#  'Neither agree nor disagree',          'Strongly disagree']
# Length: 6, dtype: str
#
# Column: Knowledge_8
# <StringArray>
# [                         nan,                      'Agree',
#  'Neither agree nor disagree',                   'Disagree',
#              'Strongly agree',          'Strongly disagree']
# Length: 6, dtype: str
#
# Column: Knowledge_9
# <StringArray>
# [                         nan,                      'Agree',
#  'Neither agree nor disagree',          'Strongly disagree',
#              'Strongly agree',                   'Disagree']
# Length: 6, dtype: str
#
# Column: Frequency_1
# <StringArray>
# [                nan,  '3-5 times a week',  '1-2 times a week',
#              'Never', '6-10 times a week',  '10+ times a week']
# Length: 6, dtype: str
#
# Column: Frequency_2
# <StringArray>
# [                nan, '6-10 times a week',  '1-2 times a week',
#   '3-5 times a week',  '10+ times a week',             'Never']
# Length: 6, dtype: str
#
# Column: Frequency_3
# <StringArray>
# [                nan, '6-10 times a week',  '1-2 times a week',
#   '3-5 times a week',             'Never',  '10+ times a week']
# Length: 6, dtype: str
#
# Column: TimeSearching
# <StringArray>
# [                         nan,        '30-60 minutes a day',
#        '60-120 minutes a day',        '15-30 minutes a day',
#  'Less than 15 minutes a day',     'Over 120 minutes a day']
# Length: 6, dtype: str
#
# Column: TimeAnswering
# <StringArray>
# [                         nan,       '60-120 minutes a day',
#         '15-30 minutes a day',        '30-60 minutes a day',
#  'Less than 15 minutes a day',     'Over 120 minutes a day']
# Length: 6, dtype: str
#
# Column: Frustration
# <StringArray>
# [                                                                                                                                                                                                                                                             nan,
#                                                                                                                                                              'Amount of technical debt;Number of software tools in use;Tracking my work;Showing my contributions',
#                                                                                                                                                                                                'Amount of technical debt;Complexity of tech stack for deployment',
#                                                                                                                 'Amount of technical debt;Complexity of tech stack for deployment;Complexity of tech stack for build;Maintaining security of code being produced',
#                                                 'Amount of technical debt;Tracking my work;Complexity of tech stack for build;Patching/updating core components;Maintaining security of systems/platforms used in work;Reliability of tools/systems used in work',
#                                                                                                                                                    'Number of software tools in use;Tracking my work;Showing my contributions;Complexity of tech stack for build',
#                                                                                                                                                                                                                                        'Amount of technical debt',
#                                                                                                                                                                                                        'Amount of technical debt;Number of software tools in use',
#                                                                                                                                                                                                                                                   'None of these',
#                                                                                                                                                      'Amount of technical debt;Tracking my work;Showing my contributions;Complexity of tech stack for deployment',
#  ...
#                                                                                                                          'Number of software tools in use;Showing my contributions;Maintaining security of code being produced;Patching/updating core components',
#                                    'Number of software tools in use;Showing my contributions;Complexity of tech stack for deployment;Complexity of tech stack for build;Patching/updating core components;Maintaining security of systems/platforms used in work',
#                                                     'Number of software tools in use;Tracking my work;Showing my contributions;Complexity of tech stack for deployment;Complexity of tech stack for build;Maintaining security of systems/platforms used in work',
#                                                                             'Showing my contributions;Complexity of tech stack for build;Maintaining security of code being produced;Patching/updating core components;Reliability of tools/systems used in work',
#               'Number of software tools in use;Tracking my work;Showing my contributions;Complexity of tech stack for build;Maintaining security of code being produced;Patching/updating core components;Maintaining security of systems/platforms used in work',
#                                                                                                                                                                                        'Tracking my work;Reliability of tools/systems used in work;None of these',
#                       'Amount of technical debt;Number of software tools in use;Tracking my work;Complexity of tech stack for deployment;Maintaining security of code being produced;Patching/updating core components;Reliability of tools/systems used in work',
#  'Number of software tools in use;Tracking my work;Complexity of tech stack for deployment;Complexity of tech stack for build;Patching/updating core components;Maintaining security of systems/platforms used in work;Reliability of tools/systems used in work',
#                                                                                     'Amount of technical debt;Number of software tools in use;Showing my contributions;Complexity of tech stack for build;Maintaining security of systems/platforms used in work',
#         'Amount of technical debt;Tracking my work;Showing my contributions;Complexity of tech stack for deployment;Maintaining security of code being produced;Maintaining security of systems/platforms used in work;Reliability of tools/systems used in work']
# Length: 955, dtype: str
#
# Column: ProfessionalTech
# <StringArray>
# [                                                                                                                                                                                                                                                              nan,
#                                                                                                                                                                                                            'DevOps function;Automated testing;Observability tools',
#                                                                                                                                                                                                                                      'Knowledge sharing community',
#                                                  'DevOps function;Automated testing;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#                                                                                                               'DevOps function;Automated testing;Observability tools;Knowledge sharing community;Continuous integration (CI) and (more often) continuous delivery',
#                                                                                                                                                                                                                                'Observability tools;Microservices',
#  'DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery',
#                                                                                                                                                                               'Automated testing;Continuous integration (CI) and (more often) continuous delivery',
#                                                                                                            'DevOps function;Automated testing;Observability tools;AI-assisted technology tool(s);Continuous integration (CI) and (more often) continuous delivery',
#                                                                                'DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Continuous integration (CI) and (more often) continuous delivery',
#  ...
#                                                                                                                                              'Automated testing;Observability tools;Developer portal or other central places to find tools/services;None of these',
#                                                                                                                                                                                                              'Automated testing;Observability tools;None of these',
#                                                                                                  'Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Innersource initiative',
#                                                                                                                               'DevOps function;Observability tools;AI-assisted technology tool(s);Developer portal or other central places to find tools/services',
#                                                                                                                                                                                                          'Knowledge sharing community;Microservices;None of these',
#                                                                                                                                   'DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);None of these',
#                                 'Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Innersource initiative',
#                                                                                                            'Automated testing;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Innersource initiative',
#                                                                                            'DevOps function;Automated testing;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Innersource initiative',
#                                                                                                                     'DevOps function;Automated testing;Observability tools;Developer portal or other central places to find tools/services;Innersource initiative']
# Length: 515, dtype: str
#
# Column: ProfessionalCloud
# <StringArray>
# [                                 nan, 'Cloud only (single or multi-cloud)',
#          'Hybrid (on-prem and cloud)',                            'On-prem']
# Length: 4, dtype: str
#
# Column: ProfessionalQuestion
# <StringArray>
# [                                                                                                             nan,
#                                                                                       'Internal Developer portal',
#                                                                                                      'A coworker',
#                                                                                'Traditional public search engine',
#                                                                                                    'Slack search',
#                                                                                                          'Other:',
#                                                                                        'AI-powered search (paid)',
#                                                                                        'AI-powered search (free)',
#  'Do search of internal share drives/storage locations for documentation (i.e., not a structured knowledge base)',
#                                                                                          'Microsoft Teams search']
# Length: 10, dtype: str
#
# Column: Industry
# <StringArray>
# [                                         nan,
#                                  'Healthcare',
#                        'Software Development',
#                  'Banking/Financial Services',
#                                      'Other:',
#                'Media & Advertising Services',
#                                   'Insurance',
#  'Internet, Telecomm or Information Services',
#                            'Higher Education',
#                                      'Energy',
#                                     'Fintech',
#                'Retail and Consumer Services',
#                               'Manufacturing',
#                                  'Government',
#        'Computer Systems Design and Services',
#             'Transportation, or Supply Chain']
# Length: 16, dtype: str
#
# Column: SurveyLength
# <StringArray>
# [nan, 'Appropriate in length', 'Too long', 'Too short']
# Length: 4, dtype: str
#
# Column: SurveyEase
# <StringArray>
# [nan, 'Easy', 'Neither easy nor difficult', 'Difficult']
# Length: 4, dtype: str

# %%
for col in cat_cols:
    print(f"\nColumn: {col}")
    print(df[col].value_counts(dropna=False))
# Out:
# Column: MainBranch
# MainBranch
# I am a developer by profession                                                           50207
# I am not primarily a developer, but I write code sometimes as part of my work/studies     6511
# I am learning to code                                                                     3875
# I code primarily as a hobby                                                               3334
# I used to be a developer by profession, but no longer am                                  1510
# Name: count, dtype: int64
#
# Column: Age
# Age
# 25-34 years old       23911
# 35-44 years old       14942
# 18-24 years old       14098
# 45-54 years old        6249
# 55-64 years old        2575
# Under 18 years old     2568
# 65 years or older       772
# Prefer not to say       322
# Name: count, dtype: int64
#
# Column: Employment
# Employment
# Employed, full-time                                                                                                                                   39041
# Independent contractor, freelancer, or self-employed                                                                                                   4846
# Student, full-time                                                                                                                                     4709
# Employed, full-time;Independent contractor, freelancer, or self-employed                                                                               3557
# Not employed, but looking for work                                                                                                                     2341
#                                                                                                                                                       ...
# Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Not employed, and not looking for work;Employed, part-time        1
# Student, full-time;Retired                                                                                                                                1
# Employed, full-time;Not employed, but looking for work;Student, part-time                                                                                 1
# Not employed, and not looking for work;Student, part-time;Employed, part-time                                                                             1
# Not employed, but looking for work;Independent contractor, freelancer, or self-employed;Student, part-time;Retired                                        1
# Name: count, Length: 110, dtype: int64
#
# Column: RemoteWork
# RemoteWork
# Hybrid (some remote, some in-person)    23015
# Remote                                  20831
# In-person                               10960
# NaN                                     10631
# Name: count, dtype: int64
#
# Column: Check
# Check
# Apples    65437
# Name: count, dtype: int64
#
# Column: CodingActivities
# CodingActivities
# NaN                                                                                                                                                                                10971
# Hobby                                                                                                                                                                               9993
# I don’t code outside of work                                                                                                                                                        6508
# Hobby;Professional development or self-paced learning from online courses                                                                                                           6203
# Hobby;Contribute to open-source projects                                                                                                                                            3732
#                                                                                                                                                                                    ...
# Other (please specify):;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work                                            1
# Other (please specify):;Bootstrapping a business;School or academic work                                                                                                               1
# Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work;Professional development or self-paced learning from online courses        1
# Hobby;Contribute to open-source projects;Other (please specify):;Bootstrapping a business;School or academic work                                                                      1
# Hobby;Other (please specify):;Bootstrapping a business;School or academic work;Professional development or self-paced learning from online courses;Freelance/contract work             1
# Name: count, Length: 119, dtype: int64
#
# Column: EdLevel
# EdLevel
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          24942
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                       15557
# Some college/university study without earning a degree                                 7651
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     5793
# NaN                                                                                    4653
# Professional degree (JD, MD, Ph.D, Ed.D, etc.)                                         2970
# Associate degree (A.A., A.S., etc.)                                                    1793
# Primary/elementary school                                                              1146
# Something else                                                                          932
# Name: count, dtype: int64
#
# Column: LearnCode
# LearnCode
# NaN                                                                                                                                                                                                        4949
# Other online resources (e.g., videos, blogs, forum, online community)                                                                                                                                      3674
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community)                                                                                                               2493
# Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc)                                                                                              2362
# Books / Physical media;Other online resources (e.g., videos, blogs, forum, online community);Online Courses or Certification                                                                               2286
#                                                                                                                                                                                                            ...
# Colleague;Other online resources (e.g., videos, blogs, forum, online community);School (i.e., University, College, etc);Online Courses or Certification;Friend or family member;Other (please specify):       1
# Colleague;On the job training;Other online resources (e.g., videos, blogs, forum, online community);Coding Bootcamp;Other (please specify):                                                                   1
# On the job training;Coding Bootcamp;Friend or family member;Other (please specify):                                                                                                                           1
# Colleague;On the job training;School (i.e., University, College, etc);Coding Bootcamp;Friend or family member                                                                                                 1
# School (i.e., University, College, etc);Coding Bootcamp;Friend or family member                                                                                                                               1
# Name: count, Length: 419, dtype: int64
#
# Column: LearnCodeOnline
# LearnCodeOnline
# NaN                                                                                                                                                                                                16200
# Technical documentation;Blogs;Written Tutorials;Stack Overflow                                                                                                                                       603
# Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow                                                                                                                                 505
# Technical documentation;Written Tutorials;Stack Overflow                                                                                                                                             384
# Technical documentation;Blogs;Books;Written Tutorials;Stack Overflow;Social Media                                                                                                                    331
#                                                                                                                                                                                                    ...
# Technical documentation;Blogs;Books;Written Tutorials;Interactive tutorial;Video-based Online Courses;Written-based Online Courses;AI;Auditory material (e.g., podcasts)                               1
# Coding sessions (live or recorded);AI;Certification videos                                                                                                                                             1
# Technical documentation;Blogs;Written Tutorials;Stack Overflow;Coding sessions (live or recorded);How-to videos;Video-based Online Courses;Written-based Online Courses;Programming Games              1
# Technical documentation;Blogs;Books;Written Tutorials;Coding sessions (live or recorded);How-to videos;Written-based Online Courses;Online challenges (e.g., daily or weekly coding challenges)        1
# Blogs;Stack Overflow;Social Media;Video-based Online Courses;Written-based Online Courses;AI                                                                                                           1
# Name: count, Length: 10854, dtype: int64
#
# Column: TechDoc
# TechDoc
# NaN                                                                                                                                                                                                                         24540
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine                                                                                           6947
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;Traditional public search engine                                                                5446
# API document(s) and/or SDK document(s);User guides or README files found in the source repository                                                                                                                            4251
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;Traditional public search engine;AI-powered search/dev tool (free)                                                         3079
#                                                                                                                                                                                                                             ...
# Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):                                                                                                    1
# Traditional public search engine;AI-powered search/dev tool (paid);Other (please specify):                                                                                                                                      1
# AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):                                                                                                                                     1
# API document(s) and/or SDK document(s);User guides or README files found in the source repository;First-party knowledge base;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):        1
# API document(s) and/or SDK document(s);First-party knowledge base;Traditional public search engine;AI-powered search/dev tool (free);AI-powered search/dev tool (paid);Other (please specify):                                  1
# Name: count, Length: 114, dtype: int64
#
# Column: YearsCode
# YearsCode
# NaN                   5568
# 10                    4561
# 5                     3723
# 6                     3496
# 8                     3449
# 7                     3333
# 4                     3290
# 15                    2813
# 20                    2636
# 12                    2559
# 3                     2518
# 9                     2251
# 14                    1822
# 25                    1671
# 2                     1642
# 11                    1636
# 13                    1477
# 30                    1461
# 16                    1401
# 18                    1228
# 17                    1038
# 40                     993
# 24                     870
# 22                     842
# 35                     735
# 1                      712
# 23                     634
# 26                     630
# Less than 1 year       569
# 19                     561
# 21                     522
# 28                     512
# 27                     504
# 32                     328
# 34                     293
# 42                     289
# 38                     285
# 29                     274
# 45                     257
# More than 50 years     254
# 36                     223
# 33                     219
# 37                     216
# 44                     195
# 43                     173
# 41                     147
# 31                     146
# 39                     145
# 46                      98
# 50                      77
# 48                      64
# 47                      63
# 49                      34
# Name: count, dtype: int64
#
# Column: YearsCodePro
# YearsCodePro
# NaN                   13827
# 2                      4168
# 3                      4093
# 5                      3526
# 10                     3251
# 4                      3215
# Less than 1 year       2856
# 6                      2843
# 1                      2639
# 8                      2549
# 7                      2517
# 12                     1777
# 15                     1635
# 20                     1549
# 9                      1493
# 11                     1312
# 13                     1127
# 14                     1082
# 25                      998
# 16                      946
# 18                      867
# 17                      814
# 30                      689
# 24                      632
# 19                      516
# 22                      492
# 23                      448
# 26                      426
# 27                      380
# 21                      380
# 28                      342
# 35                      285
# 29                      196
# 32                      194
# 40                      194
# 34                      169
# 38                      134
# 33                      132
# 36                      119
# 31                      106
# 37                      104
# 45                       56
# 42                       55
# 39                       54
# 41                       51
# More than 50 years       50
# 44                       42
# 43                       37
# 46                       21
# 50                       14
# 48                       14
# 49                       11
# 47                       10
# Name: count, dtype: int64
#
# Column: DevType
# DevType
# Developer, full-stack                            18260
# Developer, back-end                               9928
# NaN                                               5992
# Student                                           5102
# Developer, front-end                              3349
# Developer, desktop or enterprise applications     2493
# Other (please specify):                           2458
# Developer, mobile                                 2021
# Developer, embedded applications or devices       1623
# Engineering manager                               1275
# Academic researcher                               1238
# Data engineer                                     1118
# Data scientist or machine learning specialist     1024
# DevOps specialist                                 1019
# Research & Development role                        943
# Senior Executive (C-Suite, VP, etc.)               837
# Developer, game or graphics                        706
# Cloud infrastructure engineer                      634
# System administrator                               552
# Developer, AI                                      543
# Developer, QA or test                              525
# Data or business analyst                           523
# Project manager                                    418
# Security professional                              356
# Educator                                           355
# Scientist                                          332
# Engineer, site reliability                         310
# Product manager                                    290
# Blockchain                                         235
# Developer Experience                               224
# Hardware Engineer                                  200
# Designer                                           182
# Database administrator                             171
# Developer Advocate                                 105
# Marketing or sales professional                     96
# Name: count, dtype: int64
#
# Column: OrgSize
# OrgSize
# NaN                                                   17957
# 20 to 99 employees                                     9754
# 100 to 499 employees                                   8694
# 10,000 or more employees                               5558
# 1,000 to 4,999 employees                               5353
# 2 to 9 employees                                       4833
# 10 to 19 employees                                     4084
# 500 to 999 employees                                   3183
# Just me - I am a freelancer, sole proprietor, etc.     3086
# 5,000 to 9,999 employees                               1867
# I don’t know                                           1068
# Name: count, dtype: int64
#
# Column: PurchaseInfluence
# PurchaseInfluence
# I have some influence               19197
# NaN                                 18031
# I have little or no influence       17942
# I have a great deal of influence    10267
# Name: count, dtype: int64
#
# Column: BuyNewTool
# BuyNewTool
# NaN                                                                                                                                                                                                                                                                                             20256
# Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow                                                                                                                                                                                               6619
# Start a free trial;Ask developers I know/work with                                                                                                                                                                                                                                               4927
# Start a free trial;Ask developers I know/work with;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd                                                                                                                                    3007
# Start a free trial                                                                                                                                                                                                                                                                               2439
#                                                                                                                                                                                                                                                                                                 ...
# Ask developers I know/work with;Ask a generative AI tool;Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have advertised on sites I visit;Research companies that have emailed me;Other (please specify):        1
# Visit developer communities like Stack Overflow;Research companies that have emailed me;Other (please specify):                                                                                                                                                                                     1
# Visit developer communities like Stack Overflow;Read ratings or reviews on third party sites like G2 Crowd;Research companies that have emailed me;Other (please specify):                                                                                                                          1
# Ask developers I know/work with;Ask a generative AI tool;Research companies that have emailed me;Other (please specify):                                                                                                                                                                            1
# Start a free trial;Research companies that have advertised on sites I visit;Research companies that have emailed me;Other (please specify):                                                                                                                                                         1
# Name: count, Length: 216, dtype: int64
#
# Column: BuildvsBuy
# BuildvsBuy
# Is ready-to-go but also customizable for growth and targeted use cases         25972
# NaN                                                                            22079
# Is set up to be customized and needs to be engineered into a usable product     8760
# Out-of-the-box is ready to go with little need for customization                8626
# Name: count, dtype: int64
#
# Column: TechEndorse
# TechEndorse
# NaN                                                                                                                                                                                21769
# APIs;Customization;Reputation for quality and excellence                                                                                                                            1499
# APIs;Customization;Integrated developer community;Quality support system;Reputation for quality and excellence;Frequent updates to features;Connected to an open source project     1227
# APIs;Customization;Reputation for quality and excellence;Connected to an open source project                                                                                        1206
# APIs;Customization;Quality support system;Reputation for quality and excellence                                                                                                     1144
#                                                                                                                                                                                    ...
# APIs;Integrated developer community;AI tool integration;Connected to an open source project;Other:                                                                                     1
# APIs;Customization;Integrated developer community;Quality support system;AI tool integration;Frequent updates to features;Other:                                                       1
# Integrated developer community;AI tool integration;Frequent updates to features;Other:                                                                                                 1
# Customization;Integrated developer community;Quality support system;Reputation for quality and excellence;Other:                                                                       1
# APIs;Customization;Integrated developer community;Quality support system;AI tool integration;Frequent updates to features;Connected to an open source project;Other:                   1
# Name: count, Length: 387, dtype: int64
#
# Column: Country
# Country
# United States of America                                11095
# NaN                                                      6507
# Germany                                                  4947
# India                                                    4231
# United Kingdom of Great Britain and Northern Ireland     3224
#                                                         ...
# Haiti                                                       1
# Nauru                                                       1
# Chad                                                        1
# Djibouti                                                    1
# Solomon Islands                                             1
# Name: count, Length: 186, dtype: int64
#
# Column: Currency
# Currency
# NaN                          18753
# EUR European Euro            12730
# USD\tUnited States dollar    10939
# INR\tIndian rupee             2905
# GBP\tPound sterling           2614
#                              ...
# SZL\tSwazi lilangeni             1
# none\tCook Islands dollar        1
# AWG\tAruban florin               1
# BBD\tBarbadian dollar            1
# BMD\tBermudian dollar            1
# Name: count, Length: 143, dtype: int64
#
# Column: LanguageHaveWorkedWith
# LanguageHaveWorkedWith
# NaN                                                                                                                                     5692
# HTML/CSS;JavaScript;TypeScript                                                                                                          1002
# Python                                                                                                                                   832
# HTML/CSS;JavaScript;PHP;SQL                                                                                                              503
# C#                                                                                                                                       452
#                                                                                                                                         ...
# Elixir;HTML/CSS;JavaScript;Lua;PowerShell;Python;Ruby;SQL                                                                                  1
# Assembly;Bash/Shell (all shells);C;C++;Dart;HTML/CSS;Java;JavaScript;PowerShell;Rust;Solidity;SQL;TypeScript;VBA;Visual Basic (.Net)       1
# Bash/Shell (all shells);C;C#;C++;Delphi;Groovy;HTML/CSS;Java;JavaScript;Objective-C;PowerShell;Python;SQL;Swift;TypeScript                 1
# C;C++;Go;Lua;Objective-C;Python;Rust;SQL                                                                                                   1
# C;HTML/CSS;Java;JavaScript;PHP;Python;TypeScript                                                                                           1
# Name: count, Length: 23865, dtype: int64
#
# Column: LanguageWantToWorkWith
# LanguageWantToWorkWith
# NaN                                                                                                                                                              9685
# Python                                                                                                                                                            922
# Rust                                                                                                                                                              737
# HTML/CSS;JavaScript;TypeScript                                                                                                                                    632
# C#                                                                                                                                                                538
#                                                                                                                                                                  ...
# Dart;Elixir;Go;Lua;Python;Ruby;SQL;Zig                                                                                                                              1
# Elixir;Rust;Swift                                                                                                                                                   1
# Bash/Shell (all shells);C;C++;Elixir;Erlang;Go;HTML/CSS;Java;JavaScript;Kotlin;Lua;PowerShell;Python;Rust;Solidity;SQL;TypeScript;VBA;Visual Basic (.Net);Zig       1
# Bash/Shell (all shells);C;C++;Python;Ruby;SQL                                                                                                                       1
# Bash/Shell (all shells);C#;Go;HTML/CSS;Java;JavaScript;Kotlin;Objective-C;Python;Rust;SQL;Swift;TypeScript                                                          1
# Name: count, Length: 22770, dtype: int64
#
# Column: LanguageAdmired
# LanguageAdmired
# NaN                                                                                                                       14565
# Python                                                                                                                     1555
# HTML/CSS;JavaScript;TypeScript                                                                                             1058
# C#                                                                                                                          892
# Python;SQL                                                                                                                  669
#                                                                                                                           ...
# Bash/Shell (all shells);C;C#;C++;Go;HTML/CSS;Java;JavaScript;Lua;Python                                                       1
# Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PHP;SQL;TypeScript                                                     1
# Elixir;Lua;Python;Ruby;SQL                                                                                                    1
# Bash/Shell (all shells);C;C++;HTML/CSS;Java;JavaScript;PowerShell;Rust;Solidity;SQL;TypeScript;VBA;Visual Basic (.Net)        1
# Bash/Shell (all shells);C#;HTML/CSS;Java;JavaScript;Objective-C;Python;SQL;Swift;TypeScript                                   1
# Name: count, Length: 12336, dtype: int64
#
# Column: DatabaseHaveWorkedWith
# DatabaseHaveWorkedWith
# NaN                                                                                                                                     15183
# PostgreSQL                                                                                                                               3216
# Microsoft SQL Server                                                                                                                     2239
# MySQL                                                                                                                                    2099
# SQLite                                                                                                                                   1762
#                                                                                                                                         ...
# BigQuery;Clickhouse;Elasticsearch;H2;MariaDB;Microsoft Access;Microsoft SQL Server;MongoDB;MySQL;Oracle;PostgreSQL;Redis;Solr;SQLite        1
# MariaDB;Microsoft Access;MongoDB;MySQL;PostgreSQL;Redis                                                                                     1
# MySQL;Presto;Redis;TiDB                                                                                                                     1
# Dynamodb;Elasticsearch;IBM DB2;MariaDB;MySQL;PostgreSQL                                                                                     1
# Couch DB;H2;Microsoft SQL Server;MySQL;Oracle;PostgreSQL;SQLite                                                                             1
# Name: count, Length: 9051, dtype: int64
#
# Column: DatabaseWantToWorkWith
# DatabaseWantToWorkWith
# NaN                                                                                                                                                                22879
# PostgreSQL                                                                                                                                                          3738
# PostgreSQL;SQLite                                                                                                                                                   1533
# SQLite                                                                                                                                                              1476
# Microsoft SQL Server                                                                                                                                                1431
#                                                                                                                                                                    ...
# Cosmos DB;PostgreSQL;Supabase                                                                                                                                          1
# Cassandra;Databricks SQL;Snowflake                                                                                                                                     1
# Cassandra;Firebase Realtime Database;MariaDB;Microsoft Access;MongoDB;MySQL;PostgreSQL;Redis                                                                           1
# MySQL;Presto;TiDB                                                                                                                                                      1
# BigQuery;Cassandra;Databricks SQL;DuckDB;Elasticsearch;Firebase Realtime Database;Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;Redis;Snowflake;SQLite;Supabase        1
# Name: count, Length: 8479, dtype: int64
#
# Column: DatabaseAdmired
# DatabaseAdmired
# NaN                                                                                                        26880
# PostgreSQL                                                                                                  4894
# Microsoft SQL Server                                                                                        2204
# SQLite                                                                                                      1898
# MySQL                                                                                                       1769
#                                                                                                            ...
# Cosmos DB;MySQL;SQLite                                                                                         1
# Cloud Firestore;DuckDB;Microsoft Access;Redis                                                                  1
# Cassandra;Cloud Firestore;Cosmos DB;Microsoft SQL Server;MongoDB;MySQL;PostgreSQL;Redis;SQLite;Supabase        1
# MariaDB;Microsoft Access;MongoDB;MySQL;PostgreSQL;Redis                                                        1
# MySQL;Presto;TiDB                                                                                              1
# Name: count, Length: 4052, dtype: int64
#
# Column: PlatformHaveWorkedWith
# PlatformHaveWorkedWith
# NaN                                                                                                                                                                                                                                                23071
# Amazon Web Services (AWS)                                                                                                                                                                                                                           6606
# Microsoft Azure                                                                                                                                                                                                                                     4084
# Google Cloud                                                                                                                                                                                                                                        1812
# Amazon Web Services (AWS);Microsoft Azure                                                                                                                                                                                                           1521
#                                                                                                                                                                                                                                                    ...
# Alibaba Cloud;Amazon Web Services (AWS);Cloudflare;Databricks;Digital Ocean;Firebase;Google Cloud;IBM Cloud Or Watson;Managed Hosting;Microsoft Azure;Netlify;OpenStack;Oracle Cloud Infrastructure (OCI);PythonAnywhere;Scaleway;Vercel;VMware        1
# Amazon Web Services (AWS);Cloudflare;Digital Ocean;Google Cloud;Microsoft Azure;Netlify;Supabase;Vercel                                                                                                                                                1
# Amazon Web Services (AWS);Cloudflare;Digital Ocean;Google Cloud;Microsoft Azure;Netlify;PythonAnywhere;Render                                                                                                                                          1
# Alibaba Cloud;Amazon Web Services (AWS);Colocation;Databricks;Firebase;Fly.io;Google Cloud;Heroku;Managed Hosting;Microsoft Azure;Netlify;OpenStack;PythonAnywhere;Vercel;VMware                                                                       1
# Amazon Web Services (AWS);Cloudflare;Firebase;Linode, now Akamai;Vercel                                                                                                                                                                                1
# Name: count, Length: 5468, dtype: int64
#
# Column: PlatformWantToWorkWith
# PlatformWantToWorkWith
# NaN                                                                                                                   30905
# Amazon Web Services (AWS)                                                                                              4859
# Microsoft Azure                                                                                                        2782
# Google Cloud                                                                                                           1377
# Amazon Web Services (AWS);Microsoft Azure                                                                              1320
#                                                                                                                       ...
# Cloudflare;Hetzner;IBM Cloud Or Watson;Linode, now Akamai;OpenShift;Oracle Cloud Infrastructure (OCI);Render;Vultr        1
# Alibaba Cloud;Databricks;VMware                                                                                           1
# Amazon Web Services (AWS);Cloudflare;Firebase;Google Cloud;Heroku;Microsoft Azure;OVH;Vercel                              1
# Amazon Web Services (AWS);Google Cloud;Heroku;Linode, now Akamai;Vercel                                                   1
# PythonAnywhere;Render;Vercel                                                                                              1
# Name: count, Length: 4785, dtype: int64
#
# Column: PlatformAdmired
# PlatformAdmired
# NaN                                                                          34060
# Amazon Web Services (AWS)                                                     6240
# Microsoft Azure                                                               3572
# Google Cloud                                                                  1692
# Amazon Web Services (AWS);Microsoft Azure                                      905
#                                                                              ...
# Amazon Web Services (AWS);Cloudflare;Digital Ocean;Google Cloud;OpenStack        1
# Databricks;Microsoft Azure;Oracle Cloud Infrastructure (OCI)                     1
# Firebase;Microsoft Azure;Netlify;Vercel                                          1
# Amazon Web Services (AWS);Google Cloud;Heroku;Linode, now Akamai;Vercel          1
# PythonAnywhere;Render;Vercel                                                     1
# Name: count, Length: 2557, dtype: int64
#
# Column: WebframeHaveWorkedWith
# WebframeHaveWorkedWith
# NaN                                                                                                             20276
# React                                                                                                            1284
# Spring Boot                                                                                                      1083
# Node.js                                                                                                           907
# Node.js;React                                                                                                     752
#                                                                                                                 ...
# AngularJS;CodeIgniter;Django;Drupal;FastAPI;Flask;jQuery;Laravel;Node.js;Spring Boot;Symfony;WordPress;Yii 2        1
# Drupal;Express;jQuery;Laravel;Next.js;Node.js;Nuxt.js;React;Spring Boot;Symfony;Vue.js;WordPress                    1
# Angular;jQuery;Laravel;React;Ruby on Rails;WordPress                                                                1
# Django;Express;Laravel;Next.js;Node.js;Svelte;WordPress                                                             1
# Angular;AngularJS;ASP.NET;ASP.NET CORE;Drupal;jQuery;Next.js;Node.js;React;Spring Boot                              1
# Name: count, Length: 12236, dtype: int64
#
# Column: WebframeWantToWorkWith
# WebframeWantToWorkWith
# NaN                                                                                                            26902
# React                                                                                                            997
# Spring Boot                                                                                                      950
# Node.js                                                                                                          619
# ASP.NET CORE                                                                                                     607
#                                                                                                                ...
# ASP.NET;Blazor;Django;Drupal;Flask;Gatsby;jQuery;Laravel;Next.js;Node.js;Nuxt.js;React;Remix;Solid.js;Yii 2        1
# Astro;Solid.js;Svelte;Vue.js                                                                                       1
# Deno;Express;Fastify;Flask;NestJS;Node.js                                                                          1
# ASP.NET;Laravel;React;Spring Boot                                                                                  1
# Django;Express;Laravel;NestJS;Next.js;Node.js;Nuxt.js;React;Spring Boot;Symfony;Vue.js;WordPress                   1
# Name: count, Length: 11655, dtype: int64
#
# Column: WebframeAdmired
# WebframeAdmired
# NaN                                                                                     30494
# React                                                                                    1422
# Spring Boot                                                                              1272
# ASP.NET CORE                                                                             1078
# Node.js                                                                                   982
#                                                                                         ...
# Blazor;Laravel;Vue.js                                                                       1
# Angular;Express;Laravel;NestJS;Next.js;Node.js;React;Svelte;Symfony;Vue.js;WordPress        1
# ASP.NET CORE;Blazor;Express;Next.js;Node.js;Nuxt.js;React;Solid.js;Vue.js                   1
# Express;Fastify;Flask;NestJS;Node.js                                                        1
# Express;Laravel;Next.js;Node.js;Nuxt.js;React;Spring Boot;Symfony;Vue.js;WordPress          1
# Name: count, Length: 5461, dtype: int64
#
# Column: EmbeddedHaveWorkedWith
# EmbeddedHaveWorkedWith
# NaN                                                                            43223
# Rasberry Pi                                                                     3889
# Arduino;Rasberry Pi                                                             2069
# Arduino                                                                         1988
# Cargo                                                                           1008
#                                                                                ...
# Boost.Test;build2;cppunit;GNU GCC;LLVM's Clang;MSVC;PlatformIO                     1
# Catch2;CMake;cppunit;GNU GCC;QMake;Rasberry Pi                                     1
# Boost.Test;cppunit;CUTE;MSVC;Ninja;PlatformIO;ZMK                                  1
# Arduino;Boost.Test;CMake;Cargo;GNU GCC;LLVM's Clang;Ninja;QMake;Rasberry Pi        1
# Arduino;CMake;MSVC;Ninja;PlatformIO;Rasberry Pi                                    1
# Name: count, Length: 1631, dtype: int64
#
# Column: EmbeddedWantToWorkWith
# EmbeddedWantToWorkWith
# NaN                                                                  47837
# Rasberry Pi                                                           3036
# Arduino;Rasberry Pi                                                   2093
# Cargo                                                                 1226
# Arduino                                                                840
#                                                                      ...
# CMake;Meson;Ninja;QMake                                                  1
# Arduino;build2;Cargo;Meson;Micronaut;Ninja;PlatformIO;Rasberry Pi        1
# Boost.Test;build2;cppunit;GNU GCC;LLVM's Clang;MSVC;PlatformIO           1
# Boost.Test;cppunit;CUTE;MSVC;Ninja;PlatformIO;ZMK                        1
# Catch2;CMake;GNU GCC;PlatformIO                                          1
# Name: count, Length: 1472, dtype: int64
#
# Column: EmbeddedAdmired
# EmbeddedAdmired
# NaN                                                               48704
# Rasberry Pi                                                        3446
# Arduino;Rasberry Pi                                                1402
# Cargo                                                              1355
# Arduino                                                            1215
#                                                                   ...
# CMake;Meson;QMake                                                     1
# Arduino;Micronaut;PlatformIO;Rasberry Pi                              1
# Boost.Test;build2;cppunit;GNU GCC;LLVM's Clang;MSVC;PlatformIO        1
# Arduino;GNU GCC;Micronaut;Rasberry Pi                                 1
# ...
# Don’t trust the output or answers;AI tools lack context of codebase,  internal architecture, and/or company knowledge                                                                                                                                                               5502
# Don’t trust the output or answers                                                                                                                                                                                                                                                   3404
# AI tools lack context of codebase,  internal architecture, and/or company knowledge                                                                                                                                                                                                 2192
# Don’t trust the output or answers;AI tools lack context of codebase,  internal architecture, and/or company knowledge;We don’t have the right policies in place to reduce security risks                                                                                            1554
#                                                                                                                                                                                                                                                                                    ...
# Don’t trust the output or answers;AI tools lack context of codebase,  internal architecture, and/or company knowledge;Lack of proper training and education on new tools;Lack of executive buy-in;Other (please specify):;They create more work (more code/PRs to review, etc.)        1
# Lack of proper training and education on new tools;We don’t have the right policies in place to reduce security risks;Other (please specify):;They create more work (more code/PRs to review, etc.)                                                                                    1
# Not everyone uses them;We don’t have the right policies in place to reduce security risks;Other (please specify):;They create more work (more code/PRs to review, etc.)                                                                                                                1
# Don’t trust the output or answers;Lack of proper training and education on new tools;Lack of executive buy-in;Not everyone uses them;Other (please specify):;They create more work (more code/PRs to review, etc.)                                                                     1
# Don’t trust the output or answers;Lack of proper training and education on new tools;Lack of executive buy-in;Other (please specify):;They create more work (more code/PRs to review, etc.)                                                                                            1
# Name: count, Length: 233, dtype: int64
#
# Column: TBranch
# TBranch
# Yes    29960
# NaN    20960
# No     14517
# Name: count, dtype: int64
#
# Column: ICorPM
# ICorPM
# NaN                       35636
# Individual contributor    25888
# People manager             3913
# Name: count, dtype: int64
#
# Column: Knowledge_1
# Knowledge_1
# NaN                           36773
# Agree                         13454
# Strongly agree                10310
# Neither agree nor disagree     2392
# Disagree                       1813
# Strongly disagree               695
# Name: count, dtype: int64
#
# Column: Knowledge_2
# Knowledge_2
# NaN                           37416
# Agree                          9060
# Neither agree nor disagree     7284
# Disagree                       5958
# Strongly agree                 3613
# Strongly disagree              2106
# Name: count, dtype: int64
#
# Column: Knowledge_3
# Knowledge_3
# NaN                           37342
# Agree                         10979
# Neither agree nor disagree     7421
# Disagree                       5522
# Strongly agree                 2730
# Strongly disagree              1443
# Name: count, dtype: int64
#
# Column: Knowledge_4
# Knowledge_4
# NaN                           37407
# Agree                         12510
# Neither agree nor disagree     7216
# Disagree                       4188
# Strongly agree                 3257
# Strongly disagree               859
# Name: count, dtype: int64
#
# Column: Knowledge_5
# Knowledge_5
# NaN                           37557
# Agree                         14612
# Neither agree nor disagree     5097
# Strongly agree                 5005
# Disagree                       2610
# Strongly disagree               556
# Name: count, dtype: int64
#
# Column: Knowledge_6
# Knowledge_6
# NaN                           37573
# Agree                          9934
# Neither agree nor disagree     7391
# Disagree                       5900
# Strongly agree                 3673
# Strongly disagree               966
# Name: count, dtype: int64
#
# Column: Knowledge_7
# Knowledge_7
# NaN                           37659
# Agree                         10279
# Neither agree nor disagree     6546
# Disagree                       5416
# Strongly agree                 4450
# Strongly disagree              1087
# Name: count, dtype: int64
#
# Column: Knowledge_8
# Knowledge_8
# NaN                           37679
# Agree                         10759
# Neither agree nor disagree     7046
# Disagree                       5159
# Strongly agree                 3067
# Strongly disagree              1727
# Name: count, dtype: int64
#
# Column: Knowledge_9
# Knowledge_9
# NaN                           37802
# Agree                          6657
# Strongly disagree              6379
# Neither agree nor disagree     6155
# Disagree                       5890
# Strongly agree                 2554
# Name: count, dtype: int64
#
# Column: Frequency_1
# Frequency_1
# NaN                  37068
# 1-2 times a week     16989
# Never                 7607
# 3-5 times a week      2721
# 6-10 times a week      569
# 10+ times a week       483
# Name: count, dtype: int64
#
# Column: Frequency_2
# Frequency_2
# NaN                  37073
# 1-2 times a week     12578
# 3-5 times a week      6514
# 10+ times a week      3470
# 6-10 times a week     3069
# Never                 2733
# Name: count, dtype: int64
#
# Column: Frequency_3
# Frequency_3
# NaN                  37727
# 1-2 times a week     14426
# Never                 8206
# 3-5 times a week      3447
# 6-10 times a week      863
# 10+ times a week       768
# Name: count, dtype: int64
#
# Column: TimeSearching
# TimeSearching
# NaN                           36526
# 30-60 minutes a day           10951
# 15-30 minutes a day            7805
# 60-120 minutes a day           5275
# Less than 15 minutes a day     2689
# Over 120 minutes a day         2191
# Name: count, dtype: int64
#
# Column: TimeAnswering
# TimeAnswering
# NaN                           36593
# 15-30 minutes a day            9341
# 30-60 minutes a day            8642
# Less than 15 minutes a day     5918
# 60-120 minutes a day           3704
# Over 120 minutes a day         1239
# Name: count, dtype: int64
#
# Column: Frustration
# Frustration
# NaN                                                                                                                                                                                                                                                               37186
# None of these                                                                                                                                                                                                                                                      2364
# Amount of technical debt                                                                                                                                                                                                                                           2067
# Amount of technical debt;Reliability of tools/systems used in work                                                                                                                                                                                                  831
# Amount of technical debt;Complexity of tech stack for deployment;Complexity of tech stack for build                                                                                                                                                                 666
#                                                                                                                                                                                                                                                                   ...
# Tracking my work;Reliability of tools/systems used in work;None of these                                                                                                                                                                                              1
# Amount of technical debt;Number of software tools in use;Tracking my work;Complexity of tech stack for deployment;Maintaining security of code being produced;Patching/updating core components;Reliability of tools/systems used in work                             1
# Number of software tools in use;Tracking my work;Complexity of tech stack for deployment;Complexity of tech stack for build;Patching/updating core components;Maintaining security of systems/platforms used in work;Reliability of tools/systems used in work        1
# Amount of technical debt;Number of software tools in use;Showing my contributions;Complexity of tech stack for build;Maintaining security of systems/platforms used in work                                                                                           1
# Amount of technical debt;Tracking my work;Showing my contributions;Complexity of tech stack for deployment;Maintaining security of code being produced;Maintaining security of systems/platforms used in work;Reliability of tools/systems used in work               1
# Name: count, Length: 955, dtype: int64
#
# Column: ProfessionalTech
# ProfessionalTech
# NaN                                                                                                                                                                                                                                                                                       37673
# None of these                                                                                                                                                                                                                                                                              2834
# DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Innersource initiative     1068
# DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery                             706
# Automated testing;Continuous integration (CI) and (more often) continuous delivery                                                                                                                                                                                                          608
#                                                                                                                                                                                                                                                                                           ...
# DevOps function;Automated testing;Observability tools;Knowledge sharing community;AI-assisted technology tool(s);None of these                                                                                                                                                                1
# Knowledge sharing community;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Continuous integration (CI) and (more often) continuous delivery;Innersource initiative                                                              1
# Automated testing;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Innersource initiative                                                                                                                                         1
# DevOps function;Automated testing;AI-assisted technology tool(s);Microservices;Developer portal or other central places to find tools/services;Innersource initiative                                                                                                                         1
# DevOps function;Automated testing;Observability tools;Developer portal or other central places to find tools/services;Innersource initiative                                                                                                                                                  1
# Name: count, Length: 515, dtype: int64
#
# Column: ProfessionalCloud
# ProfessionalCloud
# NaN                                   36946
# Hybrid (on-prem and cloud)            13230
# Cloud only (single or multi-cloud)    11256
# On-prem                                4005
# Name: count, dtype: int64
#
# Column: ProfessionalQuestion
# ProfessionalQuestion
# NaN                                                                                                               36630
# Traditional public search engine                                                                                  15813
# A coworker                                                                                                         5324
# AI-powered search (free)                                                                                           2251
# AI-powered search (paid)                                                                                           1947
# Slack search                                                                                                       1053
# Do search of internal share drives/storage locations for documentation (i.e., not a structured knowledge base)      937
# Internal Developer portal                                                                                           777
# Other:                                                                                                              559
# Microsoft Teams search                                                                                              146
# Name: count, dtype: int64
#
# Column: Industry
# Industry
# NaN                                           36579
# Software Development                          11918
# Other:                                         3077
# Fintech                                        1641
# Internet, Telecomm or Information Services     1629
# Banking/Financial Services                     1371
# Healthcare                                     1277
# Manufacturing                                  1265
# Retail and Consumer Services                   1264
# Government                                      962
# Media & Advertising Services                    894
# Higher Education                                890
# Transportation, or Supply Chain                 859
# Computer Systems Design and Services            844
# Energy                                          578
# Insurance                                       389
# Name: count, dtype: int64
#
# Column: SurveyLength
# SurveyLength
# Appropriate in length    38767
# Too long                 16506
# NaN                       9255
# Too short                  909
# Name: count, dtype: int64
#
# Column: SurveyEase
# SurveyEase
# Easy                          30071
# Neither easy nor difficult    24581
# NaN                            9199
# Difficult                      1586
# Name: count, dtype: int64

# %% [markdown]
# <h5>3.2 Standardize entries in columns like Country or EdLevel by mapping inconsistent values to a consistent format.</h5>

# %%
## Write your code here
pd.set_option('display.max_rows', None)

df['Country'] = df['Country'].str.strip().str.lower()
df['EdLevel'] = df['EdLevel'].str.strip().str.lower()

print(df['Country'].value_counts())
print(df['EdLevel'].value_counts())
# Out:
# Country
# united states of america                                11095
# germany                                                  4947
# india                                                    4231
# united kingdom of great britain and northern ireland     3224
# ukraine                                                  2672
# france                                                   2110
# canada                                                   2104
# poland                                                   1534
# netherlands                                              1449
# brazil                                                   1375
# italy                                                    1341
# australia                                                1260
# spain                                                    1123
# sweden                                                   1016
# russian federation                                        925
# switzerland                                               876
# austria                                                   791
# czech republic                                            714
# israel                                                    604
# turkey                                                    546
# belgium                                                   526
# denmark                                                   504
# portugal                                                  470
# norway                                                    450
# romania                                                   439
# pakistan                                                  415
# iran, islamic republic of...                              411
# china                                                     406
# mexico                                                    402
# hungary                                                   396
# new zealand                                               396
# greece                                                    389
# finland                                                   386
# south africa                                              358
# indonesia                                                 354
# argentina                                                 345
# bangladesh                                                327
# bulgaria                                                  319
# nigeria                                                   305
# viet nam                                                  296
# japan                                                     288
# ireland                                                   270
# taiwan                                                    268
# egypt                                                     262
# slovakia                                                  248
# serbia                                                    245
# colombia                                                  217
# philippines                                               196
# croatia                                                   187
# lithuania                                                 183
# kenya                                                     180
# singapore                                                 177
# sri lanka                                                 163
# malaysia                                                  161
# thailand                                                  147
# south korea                                               146
# hong kong (s.a.r.)                                        146
# slovenia                                                  142
# nepal                                                     139
# chile                                                     133
# united arab emirates                                      130
# latvia                                                    128
# estonia                                                   110
# morocco                                                    98
# belarus                                                    97
# georgia                                                    94
# uruguay                                                    94
# kazakhstan                                                 81
# algeria                                                    77
# peru                                                       75
# tunisia                                                    71
# ghana                                                      70
# venezuela, bolivarian republic of...                       69
# cyprus                                                     63
# uzbekistan                                                 62
# bosnia and herzegovina                                     62
# ethiopia                                                   60
# armenia                                                    58
# republic of korea                                          57
# saudi arabia                                               56
# afghanistan                                                56
# ecuador                                                    54
# costa rica                                                 54
# albania                                                    49
# dominican republic                                         47
# lebanon                                                    46
# iraq                                                       44
# kyrgyzstan                                                 44
# nomadic                                                    43
# guatemala                                                  41
# luxembourg                                                 40
# jordan                                                     40
# paraguay                                                   39
# uganda                                                     39
# republic of moldova                                        38
# republic of north macedonia                                36
# bolivia                                                    32
# iceland                                                    31
# cameroon                                                   31
# syrian arab republic                                       30
# malta                                                      29
# united republic of tanzania                                28
# azerbaijan                                                 27
# montenegro                                                 27
# zimbabwe                                                   26
# cuba                                                       23
# rwanda                                                     22
# cambodia                                                   22
# nicaragua                                                  21
# myanmar                                                    21
# angola                                                     20
# el salvador                                                19
# kosovo                                                     18
# panama                                                     18
# yemen                                                      18
# maldives                                                   16
# honduras                                                   16
# palestine                                                  15
# mauritius                                                  15
# zambia                                                     15
# andorra                                                    15
# qatar                                                      15
# madagascar                                                 14
# côte d'ivoire                                              14
# isle of man                                                13
# malawi                                                     12
# jamaica                                                    11
# benin                                                      11
# turkmenistan                                               11
# bahrain                                                    11
# mongolia                                                   10
# senegal                                                     9
# somalia                                                     9
# togo                                                        9
# kuwait                                                      8
# trinidad and tobago                                         8
# oman                                                        8
# congo, republic of the...                                   8
# tajikistan                                                  7
# sudan                                                       7
# mozambique                                                  7
# barbados                                                    6
# namibia                                                     5
# mauritania                                                  5
# botswana                                                    5
# suriname                                                    5
# cape verde                                                  5
# antigua and barbuda                                         5
# liechtenstein                                               4
# fiji                                                        4
# gabon                                                       4
# bahamas                                                     4
# lao people's democratic republic                            4
# swaziland                                                   4
# burkina faso                                                4
# libyan arab jamahiriya                                      4
# liberia                                                     4
# san marino                                                  3
# democratic republic of the congo                            3
# burundi                                                     3
# sierra leone                                                3
# north korea                                                 3
# guyana                                                      3
# brunei darussalam                                           3
# bhutan                                                      3
# monaco                                                      3
# democratic people's republic of korea                       2
# guinea-bissau                                               2
# belize                                                      2
# mali                                                        2
# dominica                                                    1
# papua new guinea                                            1
# central african republic                                    1
# equatorial guinea                                           1
# guinea                                                      1
# niger                                                       1
# samoa                                                       1
# lesotho                                                     1
# saint kitts and nevis                                       1
# micronesia, federated states of...                          1
# haiti                                                       1
# nauru                                                       1
# chad                                                        1
# djibouti                                                    1
# solomon islands                                             1
# Name: count, dtype: int64
# EdLevel
# bachelor’s degree (b.a., b.s., b.eng., etc.)                                          24942
# master’s degree (m.a., m.s., m.eng., mba, etc.)                                       15557
# some college/university study without earning a degree                                 7651
# secondary school (e.g. american high school, german realschule or gymnasium, etc.)     5793
# professional degree (jd, md, ph.d, ed.d, etc.)                                         2970
# associate degree (a.a., a.s., etc.)                                                    1793
# primary/elementary school                                                              1146
# something else                                                                          932
# Name: count, dtype: int64

# %% [markdown]
# ### 4. Encoding Categorical Variables

# %% [markdown]
# <h5>4.1 Encode the Employment column using one-hot encoding.</h5>

# %%
## Write your code here
df_encoded = pd.get_dummies(df, columns=['Employment'])

# %%
print(df_encoded)

# %% [markdown]
# ### 5. Handling Missing Values

# %% [markdown]
# <h5>5.1 Identify columns with the highest number of missing values.</h5>

# %%
## Write your code here
# Count missing values in each column
missing_counts = df.isnull().sum()

# Sort columns by highest number of missing values
missing_counts_sorted = missing_counts.sort_values(ascending=False)

# Display the top columns with most missing values
print(missing_counts_sorted.head(10))
# Out:
# AINextMuch less integrated       64289
# AINextLess integrated            63082
# AINextNo change                  52939
# AINextMuch more integrated       51999
# EmbeddedAdmired                  48704
# EmbeddedWantToWorkWith           47837
# EmbeddedHaveWorkedWith           43223
# ConvertedCompYearly              42002
# AIToolNot interested in Using    41023
# AINextMore integrated            41009
# dtype: int64

# %% [markdown]
# <h5>5.2 Impute missing values in numerical columns (e.g., `ConvertedCompYearly`) with the mean or median.</h5>

# %%
## Write your code here
# Impute ConvertedCompYearly with median
df['ConvertedCompYearly'] = df['ConvertedCompYearly'].fillna(df['ConvertedCompYearly'].median())

# %% [markdown]
# <h5>5.3 Impute missing values in categorical columns (e.g., `RemoteWork`) with the most frequent value.</h5>

# %%
## Write your code here
# Fill missing values with the most frequent value (mode)
df['RemoteWork'] = df['RemoteWork'].fillna(df['RemoteWork'].mode()[0])

# %% [markdown]
# ### 6. Feature Scaling and Transformation

# %% [markdown]
# <h5>6.1 Apply Min-Max Scaling to normalize the `ConvertedCompYearly` column.</h5>

# %%
## Write your code here
# Apply Min-Max Scaling
df['ConvertedCompYearly_MinMax'] = (
    (df['ConvertedCompYearly'] - df['ConvertedCompYearly'].min()) /
    (df['ConvertedCompYearly'].max() - df['ConvertedCompYearly'].min())
)

# %% [markdown]
# <h5>6.2 Log-transform the ConvertedCompYearly column to reduce skewness.</h5>

# %%
## Write your code here
# Log-transform the ConvertedCompYearly
df['ConvertedCompYearly_Log'] = np.log(df['ConvertedCompYearly'])

# %% [markdown]
# ### 7. Feature Engineering

# %% [markdown]
# <h5>7.1 Create a new column `ExperienceLevel` based on the `YearsCodePro` column:</h5>

# %%
## Write your code here
# Convert to numeric (coerce invalid values to NaN)
df['YearsCodePro'] = pd.to_numeric(df['YearsCodePro'], errors='coerce')

# %% [markdown]
# ### Summary

# %% [markdown]
# In this lab, you:
#
# - Explored the dataset to identify inconsistencies and missing values.
#
# - Encoded categorical variables for analysis.
#
# - Handled missing values using imputation techniques.
#
# - Normalized and transformed numerical data to prepare it for analysis.
#
# - Engineered a new feature to enhance data interpretation.

# %% [markdown]
# Copyright © IBM Corporation. All rights reserved.
